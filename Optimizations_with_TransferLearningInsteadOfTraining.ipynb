# %% [markdown]
# <a href="https://colab.research.google.com/github/KlyffHanger/TinyML/blob/main/Optimizations_with_TransferLearningInsteadOfTraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tf_version = "2.19.0"
hub_version = "0.16.1"
datasets_version = "4.9.9"
numpy_version = "2.0.2"
protobuf_version = "3.20.3"

import tensorflow as tf
import numpy as np

try:
    import tensorflow_hub as hub
    import tensorflow_datasets as tfds
except:
    hub = None
    tfds = None

# Check if versions match
if (tf.__version__ != tf_version or
    (hub and hub.__version__ != hub_version) or
    (tfds and tfds.__version__ != datasets_version) or
    not np.__version__.startswith(numpy_version)):

    print(f"Current TensorFlow version: {tf.__version__} → {tf_version}")
    if hub: print(f"Current TensorFlow Hub version: {hub.__version__} → {hub_version}")
    if tfds: print(f"Current TensorFlow Datasets version: {tfds.__version__} → {datasets_version}")
    print(f"Current NumPy version: {np.__version__} → {numpy_version}")

    # Uninstall old versions
    # !pip uninstall -y tensorflow tensorflow_hub tensorflow_datasets numpy protobuf

    # Install specific versions
    # !pip install tensorflow=={tf_version} \
                tensorflow_hub=={hub_version} \
                tensorflow_datasets=={datasets_version} \
                numpy=={numpy_version} \
                protobuf=={protobuf_version}

    # Prompt user to restart
    print("\n Specified versions installed successfully.")
    print(" Please restart the runtime (Runtime > Restart session) and re-run the notebook.\n")
else:
    print(" All packages are already at the specified versions.")
# Out:
#  All packages are already at the specified versions.

# %%
import numpy as np
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
setattr(tfds.image_classification.cats_vs_dogs, '_URL',"https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip")


def format_image(image, label):
    image = tf.image.resize(image, (224, 224)) / 255.0
    return  image, label

#Prepare the data for training, validation and test

(raw_train, raw_validation, raw_test), metadata = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)

num_examples = metadata.splits['train'].num_examples
num_classes = metadata.features['label'].num_classes
print(num_examples)
print(num_classes)

BATCH_SIZE = 32
train_batches = raw_train.shuffle(num_examples // 4).map(format_image).batch(BATCH_SIZE).prefetch(1)
validation_batches = raw_validation.map(format_image).batch(BATCH_SIZE).prefetch(1)
test_batches = raw_test.map(format_image).batch(1)

for image_batch, label_batch in train_batches.take(1):
    pass

image_batch.shape
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/cats_vs_dogs/4.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cats_vs_dogs/4.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/incomplete.SI4DGB_4.0.1/cats_vs_dogs-train.tfrecord*...:   0%…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.1. Subsequent calls will reuse this data.
# 23262
# 2
# TensorShape([32, 224, 224, 3])

# %% [markdown]
# Training the model over 5 epochs

# %%
# 1. Load the base model from Keras applications - here we are downloading a model called MobileNetV2 and do transfer learning on that
base_model = tf.keras.applications.MobileNetV2(
input_shape=(224, 224, 3),
include_top=False,
weights='imagenet')
# 2. Freeze the base model
base_model.trainable = False
# 3. Create the new model on top
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(), # This layer flattens the feature map
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
model.summary()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Running only 5 epochs since this is not a new model that we are training but only doing transfer learning
EPOCHS = 5

hist = model.fit(train_batches,
                 epochs=EPOCHS,
                 validation_data=validation_batches)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │         2,562 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,260,546 (8.62 MB)
#  Trainable params: 2,562 (10.01 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Epoch 1/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 77s 94ms/step - accuracy: 0.9560 - loss: 0.1152 - val_accuracy: 0.9789 - val_loss: 0.0551
# Epoch 2/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 37s 53ms/step - accuracy: 0.9836 - loss: 0.0452 - val_accuracy: 0.9802 - val_loss: 0.0522
# Epoch 3/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 35s 49ms/step - accuracy: 0.9856 - loss: 0.0389 - val_accuracy: 0.9832 - val_loss: 0.0495
# Epoch 4/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9882 - loss: 0.0342 - val_accuracy: 0.9819 - val_loss: 0.0511
# Epoch 5/5
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9894 - loss: 0.0299 - val_accuracy: 0.9828 - val_loss: 0.0503

# %% [markdown]
# Saving the model by model.export in Keras

# %%
CATS_VS_DOGS_SAVED_MODEL_DIR = "exp_saved_model"
model.export(CATS_VS_DOGS_SAVED_MODEL_DIR)
# Out:
# Saved artifact at 'exp_saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   138239801160528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801161104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801163216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801162256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801160720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801162832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801162640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801160912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801157648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801163024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769183632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769183824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239801163600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769182672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769184400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769186512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769186704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769184976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769183440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769187280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769186896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769185360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769189008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769188432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769188816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769189392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769189584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769189776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769185744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769190928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769191312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769191504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769190544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769191120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769192080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769192464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769192656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769191696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769192272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769193232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769190736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769192848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769190160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769194192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769193616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769193808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769194000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769190352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769195152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769194576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769194768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769194960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769191888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769196112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769195536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769195728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769195920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769193424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769197072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769196496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769196688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769196880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769194384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769198032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769197456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769195344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769198224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769197648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769198416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769197840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769641808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769641616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769196304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769197264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769641040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769642192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769642000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769641232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769643344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769642768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769642960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769643152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769642384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769644304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769643728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769643920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769644112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769641424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769645264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769644688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769644880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769645072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769642576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769646224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769645648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769645840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769646032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769643536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769647184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769646608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769646800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769646992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769644496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769648144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769647568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769647760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769647952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769645456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769649104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769648528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769648720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769648912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769646416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769650064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769649680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769649872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769650640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769648336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769651984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769651792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769652944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769652560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769650256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769653904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769653520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769653712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769654480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769654672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769652176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769655824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769655248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769655440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769655632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769654096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924650448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239769656016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924650256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924650064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924650640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924652368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924651792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924651984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924652176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924652752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924652944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924650832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924654288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924653712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924653904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924654096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924651600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924655248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924654672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924652560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924655632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924655824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924656016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924653520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924654480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924655440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924660624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768642000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768642960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239924665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768642768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768641808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768641616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768642192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768643920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768642576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138239768643152: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# Now convert the saved model to work with TFLite using the TFLiteConverter

# %%
import pathlib
converter = tf.lite.TFLiteConverter.from_saved_model(CATS_VS_DOGS_SAVED_MODEL_DIR)

# These options are for converter optimizaitons
# Consider trying the converter without them and
# explore model size and accuracy
# Then...use them and reconvert the model and explore model
# size an accuracy at that point. What differences do you see?

converter.optimizations = [tf.lite.Optimize.DEFAULT]    # Uncomment this line for Model 2 and Model 3

def representative_data_gen():                          # Uncomment the following 5 lines for Model 3
    for input_value, _ in test_batches.take(100):
        yield [input_value]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

tflite_model = converter.convert()
tflite_models_dir = pathlib.Path("/tmp/")

tflite_model_file = tflite_models_dir/'model3.tflite'
tflite_model_file.write_bytes(tflite_model)
# This will report back the file size in bytes
# model 1 - 8874204
# model 2 - 2508336 with default optimizations at the time of converting
# model 3 - 2711688
# Out:
# 2711688

# %% [markdown]
# Let us compare the size of the models after conversion

# %%
import os

saved_model_size = sum(os.path.getsize(os.path.join(dirpath, filename)) for dirpath, dirnames, filenames in os.walk(CATS_VS_DOGS_SAVED_MODEL_DIR) for filename in filenames)
print(f"SavedModel directory size: {saved_model_size / (1024*1024):.2f} MB")

tflite_model_size = os.path.getsize(tflite_models_dir/'model1.tflite')
print(f"TFLite model file size without optimizations: {tflite_model_size / (1024*1024):.2f} MB")

tflite_model_size = os.path.getsize(tflite_models_dir/'model2.tflite')
print(f"TFLite model file size with default optimizations: {tflite_model_size / (1024*1024):.2f} MB")

tflite_model_size = os.path.getsize(tflite_models_dir/'model3.tflite')
print(f"TFLite model file size with quantization into INT8: {tflite_model_size / (1024*1024):.2f} MB")
# Out:
# SavedModel directory size: 18.90 MB
# TFLite model file size without optimizations: 8.46 MB
# TFLite model file size with default optimizations: 2.39 MB
# TFLite model file size with quantization into INT8: 2.59 MB

# %% [markdown]
# Now let us test ALL the TFLite models for their accuracy

# %%
from tqdm import tqdm
# Load TFLite model and allocate tensors.
tflite_model_file = '/tmp/model3.tflite' # load different models here for their accuracy check
interpreter = tf.lite.Interpreter(model_path=tflite_model_file)
interpreter.allocate_tensors()

input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]

predictions = []

# This will report how many iterations per second, where each
# iteration is 100 predictions
# Take 100 images from the test batch and test the accuracy
test_labels, test_imgs = [], []
for img, label in tqdm(test_batches.take(100)):
    interpreter.set_tensor(input_index, img)
    interpreter.invoke()
    predictions.append(interpreter.get_tensor(output_index))

    test_labels.append(label.numpy()[0])
    test_imgs.append(img)


# This will tell you how many of the predictions were correct
score = 0
for item in range(0,len(predictions)):
  prediction=np.argmax(predictions[item])
  label = test_labels[item]
  if prediction==label:
    score=score+1

print("Out of 100 predictions I got " + str(score) + " correct")

# model 1 - 80.96 it/s - 100 correct
# model 2 - 33.30it/s - 100 correct
# model 3 - 41.80it/s - 99 correct
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# 100%|██████████| 100/100 [00:01<00:00, 57.26it/s]
# Out of 100 predictions I got 99 correct

# %%
#@title Utility functions for plotting
# Utilities for plotting

class_names = ['cat', 'dog']

def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    img = np.squeeze(img)

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)

    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                         100*np.max(predictions_array),
                                         class_names[true_label]), color=color)

# %%
#@title Visualize the outputs { run: "auto" }
max_index = 10 #@param {type:"slider", min:1, max:100, step:1}
for index in range(0,max_index):
  plt.figure(figsize=(6,3))
  plt.subplot(1,2,1)
  plot_image(index, predictions, test_labels, test_imgs)
  plt.show()
